# %% [markdown]
# # Preparation

# %%
# !pip install faiss-cpu open-clip-torch Pillow requests
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting open-clip-torch
#   Downloading open_clip_torch-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (0.21.0+cu124)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (2024.11.6)
# Collecting ftfy (from open-clip-torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (0.30.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (0.5.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from open-clip-torch) (1.0.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.9.0->open-clip-torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9.0->open-clip-torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9.0->open-clip-torch) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->open-clip-torch) (0.2.13)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->open-clip-torch) (6.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9.0->open-clip-torch) (3.0.2)
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 22.3 MB/s eta 0:00:00
# Downloading open_clip_torch-2.32.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.5 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ftfy, faiss-cpu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, open-clip-torch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed faiss-cpu-1.10.0 ftfy-6.3.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 open-clip-torch-2.32.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import faiss
import requests
from PIL import Image
from io import BytesIO
import open_clip
import numpy as np

# %%
# URL of the JSONL file
url = "https://huggingface.co/datasets/McAuley-Lab/Amazon-Reviews-2023/resolve/main/raw/meta_categories/meta_Amazon_Fashion.jsonl"

# Local filename to save the file
output_file = "meta_Amazon_Fashion.jsonl"

# Send GET request
response = requests.get(url, stream=True)

# Check if request was successful
if response.status_code == 200:
    with open(output_file, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)
    print(f"File downloaded successfully and saved as '{output_file}'")
else:
    print(f"Failed to download file. Status code: {response.status_code}")
# Out:
# File downloaded successfully and saved as 'meta_Amazon_Fashion.jsonl'

# %% [markdown]
# ## Data preparation

# %%
EXTRACT_SIZE = 100000

# %%
# Path to the JSONL file
file_path = "meta_Amazon_Fashion.jsonl"

# Load JSONL into a pandas DataFrame
#extract_df = pd.read_json(file_path, lines=True)

# Read the first lines manually
with open(file_path, 'r', encoding='utf-8') as f:
    lines = [next(f) for _ in range(EXTRACT_SIZE)]

# Convert the lines (as strings) into a DataFrame
extract_df = pd.read_json(''.join(lines), lines=True)
# Out:
# <ipython-input-5-bd98cc441e7c>:12: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   extract_df = pd.read_json(''.join(lines), lines=True)

# %%
def contains_default_amazon_image(image_array):
  for dico in image_array:
    if '.gif' in dico['thumb']:
      return True
  return False
extract_df["default_image"] = extract_df["images"].apply(contains_default_amazon_image)

# %%
extract_df.head(10)
# Out:
#     main_category                                              title  \
# 0  AMAZON FASHION  YUEDGE 5 Pairs Men's Moisture Control Cushione...
# 1  AMAZON FASHION  DouBCQ Women's Palazzo Lounge Wide Leg Casual ...
# 2  AMAZON FASHION  Pastel by Vivienne Honey Vanilla Girls' Trapez...
# 3  AMAZON FASHION                                   Mento Streamtail
# 4  AMAZON FASHION  RONNOX Women's 3-Pairs Bright Colored Calf Com...
# 5  AMAZON FASHION  12pairs Egowz High Visibility Nylon Latex Foam...
# 6  AMAZON FASHION  Nemidor Women's Vintage 1950s Style Sleeved Pl...
# 7  AMAZON FASHION  YUNXI 3D grape Drop Earrings Cute Fruit Gold D...
# 8  AMAZON FASHION  LYCKYY Women's Tie Dye Sweatshirt Crewneck Lon...
# 9  AMAZON FASHION  PattyBoutik Women Crewneck Eyelet Cold Shoulde...
#
#    average_rating  rating_number  \
# 0             4.6             16
# 1             4.1              7
# 2             4.3             11
# 3             2.0              1
# 4             4.3           3032
# 5             5.0              3
# 6             4.0              6
# 7             4.7             13
# 8             3.7             52
# 9             4.6              5
#
#                                             features  \
# 0                                                 []
# 1                 [Drawstring closure, Machine Wash]
# 2                   [Zipper closure, Hand Wash Only]
# 3  [Thermoplastic Rubber sole, High Density Premi...
# 4  [Pull On closure, Size Guide: "S" fits calf 10...
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                  [Pull On closure]
# 9                      [97% Cotton, 3% Other Fibers]
#
#                                          description  price  \
# 0                                                 []    NaN
# 1                                                 []    NaN
# 2                                                 []    NaN
# 3  [Slip on the Women's Mento and you're ready to...  29.81
# 4  [Ronnox Calf Sleeves - Allowing Your Body to P...  17.99
# 5                                                 []    NaN
# 6                                                 []    NaN
# 7                                                 []    NaN
# 8  [Tie dye shirts for Women long sleeve crewneck...   9.99
# 9                                                 []    NaN
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
# 3  [{'thumb': 'https://m.media-amazon.com/images/...
# 4  [{'thumb': 'https://m.media-amazon.com/images/...
# 5  [{'thumb': 'https://m.media-amazon.com/images/...
# 6  [{'thumb': 'https://m.media-amazon.com/images/...
# 7  [{'thumb': 'https://m.media-amazon.com/images/...
# 8  [{'thumb': 'https://m.media-amazon.com/images/...
# 9  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos               store  \
# 0                                                 []            GiveGift
# 1                                                 []              DouBCQ
# 2                                                 []  Pastel by Vivienne
# 3                                                 []          Guy Harvey
# 4  [{'title': 'HONEST Review: RONNOX Women's 3-Pa...              RONNOX
# 5                                                 []              KEMUKR
# 6                                                 []             Nemidor
# 7  [{'title': 'Cubic Zirconia Pearl Drop Earrings...               YUNXI
# 8                                                 []              LYCKYY
# 9                                                 []         PattyBoutik
#
#   categories                                            details parent_asin  \
# 0         []  {'Package Dimensions': '10.31 x 8.5 x 1.73 inc...  B08BHN9PK5
# 1         []  {'Package Dimensions': '15 x 10.2 x 0.4 inches...  B08R39MRDW
# 2         []  {'Is Discontinued By Manufacturer': 'No', 'Pac...  B077KJHCJ4
# 3         []  {'Package Dimensions': '11.22 x 4.72 x 4.33 in...  B0811M2JG9
# 4         []  {'Is Discontinued By Manufacturer': 'No', 'Pac...  B07SB2892S
# 5         []  {'Brand': 'KEMUKR', 'Reusability': 'Reusable',...  B07NZ7V22C
# 6         []  {'Is Discontinued By Manufacturer': 'No', 'Pro...  B01ISW76HQ
# 7         []  {'Package Dimensions': '4.13 x 3.03 x 0.47 inc...  B08T6KT3N8
# 8         []  {'Department': 'womens', 'Date First Available...  B08FMLXY1Z
# 9         []  {'Is Discontinued By Manufacturer': 'No', 'Pac...  B07DXHY5ZX
#
#    bought_together  default_image
# 0              NaN          False
# 1              NaN          False
# 2              NaN          False
# 3              NaN          False
# 4              NaN          False
# 5              NaN          False
# 6              NaN          False
# 7              NaN          False
# 8              NaN          False
# 9              NaN          False

# %%
# Filter null GIFS
extract_df = extract_df[extract_df["default_image"] == False]

# %%
# Create the dictionary of idx to URL
images_url_dict = {np.int64(idx): images[0]["large"] for idx, images in extract_df['images'].items()}

# %%
extracted_image_urls = list(images_url_dict.values())
extracted_indices = list(images_url_dict.keys())

# %% [markdown]
# # Proto

# %% [markdown]
# ## Create vector DB

# %%
dim = 512
index_flat = faiss.IndexFlatIP(dim)  # cosine similarity (normalized vectors)
index = faiss.IndexIDMap(index_flat)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tqdm.auto import tqdm
from datetime import datetime

# Device setup
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Load CLIP model
model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')
model = model.to(device).eval()

# Storage
embeddings_list = []
ids = []
url_to_index = {}  # optional mapping for later lookup
# Process each image URL
for idx, url in tqdm(enumerate(extracted_image_urls)):
    try:
        response = requests.get(url)
        image = Image.open(BytesIO(response.content)).convert("RGB")
        image_tensor = preprocess(image).unsqueeze(0).to(device)

        with torch.no_grad():
            embedding = model.encode_image(image_tensor).cpu().numpy().astype('float32')
            embedding /= np.linalg.norm(embedding)  # normalize for cosine similarity

        embeddings_list.append(embedding[0])  # squeeze batch dim
        ids.append(extracted_indices[idx])
        url_to_index[url] = idx

        print(f"Processed {idx+1}/{len(extracted_image_urls)}: {url}")
        print(f"Index in DB: {extracted_indices[idx]}")

        if idx % 1000 == 0:
          embedding_array = np.array(embeddings_list)
          ids = np.array(ids, dtype='int64')
          index.add_with_ids(embedding_array, ids)
          current_time = datetime.now().strftime("%Y%m%d%H%M%S")
          index_path = "/content/drive/My Drive/EXPORT_faiss_size_" + str(EXTRACT_SIZE) + "_CLIP_idx_" + str(idx) + "_" + current_time + ".index"
          faiss.write_index(index, index_path)
          print(f"FAISS index built with {index.ntotal} vectors.")
          embeddings_list = []
          ids = []

    except Exception as e:
        print(f"Failed to process {url}: {e}")

# Build FAISS index
if embeddings_list:
    # Create array of embeddings and corresponding IDs
    embedding_array = np.array(embeddings_list)
    ids = np.array(ids, dtype='int64')
    index.add_with_ids(embedding_array, ids)
    print(f"FAISS index built with {index.ntotal} vectors.")
else:
    print("No embeddings created.")
# Current time
current_time = datetime.now().strftime("%Y%m%d%H%M%S")
index_path = "/content/drive/My Drive/EXPORT_faiss_size_" + str(EXTRACT_SIZE) + "_CLIP_total_" + current_time + ".index"
faiss.write_index(index, index_path)
# Out:
# Using device: cuda
# 0it [00:00, ?it/s]
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Processed 57145/98662: https://m.media-amazon.com/images/I/31meFjlj0mL._AC_.jpg
# Index in DB: 57924
# Processed 57146/98662: https://m.media-amazon.com/images/I/31u0BCrdiQL._AC_.jpg
# Index in DB: 57925
# Processed 57147/98662: https://m.media-amazon.com/images/I/415AVT8s8VL._AC_.jpg
# Index in DB: 57926
# Processed 57148/98662: https://m.media-amazon.com/images/I/317D5I4ao7L._AC_.jpg
# Index in DB: 57927
# Processed 57149/98662: https://m.media-amazon.com/images/I/41KseSZpYXL._AC_.jpg
# Index in DB: 57928
# Processed 57150/98662: https://m.media-amazon.com/images/I/31pchBwl2bL._AC_.jpg
# Index in DB: 57929
# Processed 57151/98662: https://m.media-amazon.com/images/I/411cOT0TiJL._AC_.jpg
# Index in DB: 57930
# Processed 57152/98662: https://m.media-amazon.com/images/I/51A9qDRFoxL._AC_.jpg
# Index in DB: 57931
# Processed 57153/98662: https://m.media-amazon.com/images/I/41xg8Y0uUcL._AC_.jpg
# Index in DB: 57932
# Processed 57154/98662: https://m.media-amazon.com/images/I/416d0IQhpfL._AC_.jpg
# Index in DB: 57933
# Processed 57155/98662: https://m.media-amazon.com/images/I/51egHzvV54L._AC_.jpg
# Index in DB: 57934
# Processed 57156/98662: https://m.media-amazon.com/images/I/41Xqw+iEsCL._AC_.jpg
# Index in DB: 57935
# Processed 57157/98662: https://m.media-amazon.com/images/I/31uID8LE91L._AC_.jpg
# Index in DB: 57936
# Processed 57158/98662: https://m.media-amazon.com/images/I/51mnq-7PRYL._AC_.jpg
# Index in DB: 57937
# Processed 57159/98662: https://m.media-amazon.com/images/I/31pMrO0GzVL._AC_.jpg
# Index in DB: 57938
# Processed 57160/98662: https://m.media-amazon.com/images/I/41410hETLtL._AC_.jpg
# Index in DB: 57939
# Processed 57161/98662: https://m.media-amazon.com/images/I/41BpzxsL5LL._AC_.jpg
# Index in DB: 57940
# Processed 57162/98662: https://m.media-amazon.com/images/I/31M9Z+f2FPL._AC_.jpg
# Index in DB: 57941
# Processed 57163/98662: https://m.media-amazon.com/images/I/31IMvH96-cL._AC_.jpg
# Index in DB: 57942
# Processed 57164/98662: https://m.media-amazon.com/images/I/41ckERySEVL._AC_.jpg
# Index in DB: 57943
# Processed 57165/98662: https://m.media-amazon.com/images/I/412gNi0JZDL._AC_.jpg
# Index in DB: 57944
# Processed 57166/98662: https://m.media-amazon.com/images/I/418i3DIdDXL._AC_.jpg
# Index in DB: 57945
# Processed 57167/98662: https://m.media-amazon.com/images/I/41IZr0wapKL._AC_.jpg
# Index in DB: 57946
# Processed 57168/98662: https://m.media-amazon.com/images/I/31AONLpXyxL._AC_.jpg
# Index in DB: 57947
# Processed 57169/98662: https://m.media-amazon.com/images/I/41FVl0MVN9L._AC_.jpg
# Index in DB: 57948
# Processed 57170/98662: https://m.media-amazon.com/images/I/31D40ecs7oL._AC_.jpg
# Index in DB: 57949
# Processed 57171/98662: https://m.media-amazon.com/images/I/31rIUpxKUnL._AC_.jpg
# Index in DB: 57950
# Processed 57172/98662: https://m.media-amazon.com/images/I/41BkAkrjq0L._AC_.jpg
# Index in DB: 57951
# Processed 57173/98662: https://m.media-amazon.com/images/I/41uLMJxi-1S._AC_.jpg
# Index in DB: 57952
# Processed 57174/98662: https://m.media-amazon.com/images/I/31RLHYkh3YL._AC_.jpg
# Index in DB: 57953
# Processed 57175/98662: https://m.media-amazon.com/images/I/51V9AOluxHL._AC_.jpg
# Index in DB: 57954
# Processed 57176/98662: https://m.media-amazon.com/images/I/41tWb7T7oIL._AC_.jpg
# Index in DB: 57955
# Processed 57177/98662: https://m.media-amazon.com/images/I/51yxsYj12pL._AC_.jpg
# Index in DB: 57956
# Processed 57178/98662: https://m.media-amazon.com/images/I/31xnSMJ47pL._AC_.jpg
# Index in DB: 57957
# Processed 57179/98662: https://m.media-amazon.com/images/I/41jdNyGCyAL._AC_.jpg
# Index in DB: 57958
# Processed 57180/98662: https://m.media-amazon.com/images/I/51mUVDINqZL._AC_.jpg
# Index in DB: 57959
# Processed 57181/98662: https://m.media-amazon.com/images/I/41UxlwaZUPL._AC_.jpg
# Index in DB: 57960
# Processed 57182/98662: https://m.media-amazon.com/images/I/21-GsbRhatL._AC_.jpg
# Index in DB: 57961
# Processed 57183/98662: https://m.media-amazon.com/images/I/414Dev5WBqL._AC_.jpg
# Index in DB: 57962
# Processed 57184/98662: https://m.media-amazon.com/images/I/41W9vU1aHfL._AC_.jpg
# Index in DB: 57963
# Processed 57185/98662: https://m.media-amazon.com/images/I/41xbbdnqpxL._AC_.jpg
# Index in DB: 57964
# Processed 57186/98662: https://m.media-amazon.com/images/I/41pzVI16vrL._AC_.jpg
# Index in DB: 57965
# Processed 57187/98662: https://m.media-amazon.com/images/I/419K4-yxmmL._AC_.jpg
# Index in DB: 57966
# Processed 57188/98662: https://m.media-amazon.com/images/I/312Z2xe10lL._AC_.jpg
# Index in DB: 57967
# Processed 57189/98662: https://m.media-amazon.com/images/I/41Li8uudMsL._AC_.jpg
# Index in DB: 57968
# Processed 57190/98662: https://m.media-amazon.com/images/I/41L+Ge6GqHL._AC_.jpg
# Index in DB: 57969
# Processed 57191/98662: https://m.media-amazon.com/images/I/31SO9di9w8L._AC_.jpg
# Index in DB: 57970
# Processed 57192/98662: https://m.media-amazon.com/images/I/41yis0qE7DL._AC_.jpg
# Index in DB: 57971
# Processed 57193/98662: https://m.media-amazon.com/images/I/31ddOAkDO8L._AC_.jpg
# Index in DB: 57972
# Processed 57194/98662: https://m.media-amazon.com/images/I/51WJ6nt-VeL._AC_.jpg
# Index in DB: 57973
# Processed 57195/98662: https://m.media-amazon.com/images/I/41iktFTCcXL._AC_.jpg
# Index in DB: 57974
# Processed 57196/98662: https://m.media-amazon.com/images/I/31KBx-1jrxL._AC_.jpg
# Index in DB: 57975
# Processed 57197/98662: https://m.media-amazon.com/images/I/41yKGgg4VwL._AC_.jpg
# Index in DB: 57976
# Processed 57198/98662: https://m.media-amazon.com/images/I/51EusdLp0GL._AC_.jpg
# Index in DB: 57977
# Processed 57199/98662: https://m.media-amazon.com/images/I/31xnvtQ41HL._AC_.jpg
# Index in DB: 57978
# Processed 57200/98662: https://m.media-amazon.com/images/I/51OMuUe3vlL._AC_.jpg
# Index in DB: 57980
# Processed 57201/98662: https://m.media-amazon.com/images/I/51U1ogIP0uL._AC_.jpg
# Index in DB: 57981
# Processed 57202/98662: https://m.media-amazon.com/images/I/51pmX5yws8L._AC_.jpg
# Index in DB: 57982
# Processed 57203/98662: https://m.media-amazon.com/images/I/31pmoUGya7L._AC_.jpg
# Index in DB: 57983
# Processed 57204/98662: https://m.media-amazon.com/images/I/51l-i5cBbuL._AC_.jpg
# Index in DB: 57984
# Processed 57205/98662: https://m.media-amazon.com/images/I/41rkDxivz8L._AC_.jpg
# Index in DB: 57985
# Processed 57206/98662: https://m.media-amazon.com/images/I/5136lfqPBfL._AC_.jpg
# Index in DB: 57986
# Processed 57207/98662: https://m.media-amazon.com/images/I/51AGL-+VhQL._AC_.jpg
# Index in DB: 57987
# Processed 57208/98662: https://m.media-amazon.com/images/I/31zGN+jjDsL._AC_.jpg
# Index in DB: 57988
# Processed 57209/98662: https://m.media-amazon.com/images/I/31rlctFdF0L._AC_.jpg
# Index in DB: 57989
# Processed 57210/98662: https://m.media-amazon.com/images/I/51UVjeg1aUL._AC_.jpg
# Index in DB: 57990
# Processed 57211/98662: https://m.media-amazon.com/images/I/518bAM0oMrL._AC_.jpg
# Index in DB: 57991
# Processed 57212/98662: https://m.media-amazon.com/images/I/41B5wpi7gQL._AC_.jpg
# Index in DB: 57992
# Processed 57213/98662: https://m.media-amazon.com/images/I/41u-pCG54PL._AC_.jpg
# Index in DB: 57993
# Processed 57214/98662: https://m.media-amazon.com/images/I/51e+3sIlr9L._AC_.jpg
# Index in DB: 57994
# Processed 57215/98662: https://m.media-amazon.com/images/I/51Z-QkeZO9L._AC_.jpg
# Index in DB: 57995
# Processed 57216/98662: https://m.media-amazon.com/images/I/51ysk-713UL._AC_.jpg
# Index in DB: 57996
# Processed 57217/98662: https://m.media-amazon.com/images/I/51paeiCHpxL._AC_.jpg
# Index in DB: 57997
# Processed 57218/98662: https://m.media-amazon.com/images/I/41GIacDOEEL._AC_.jpg
# Index in DB: 57998
# Processed 57219/98662: https://m.media-amazon.com/images/I/51TvokFAOVL._AC_.jpg
# Index in DB: 57999
# Processed 57220/98662: https://m.media-amazon.com/images/I/41dBpzDVjEL._AC_.jpg
# Index in DB: 58000
# Processed 57221/98662: https://m.media-amazon.com/images/I/51B-9wIUUSL._AC_.jpg
# Index in DB: 58001
# Processed 57222/98662: https://m.media-amazon.com/images/I/51ndpbU5NLL._AC_.jpg
# Index in DB: 58002
# Processed 57223/98662: https://m.media-amazon.com/images/I/31UZOadKqJL._AC_.jpg
# Index in DB: 58003
# Processed 57224/98662: https://m.media-amazon.com/images/I/51NHQeF7AAL._AC_.jpg
# Index in DB: 58004
# Processed 57225/98662: https://m.media-amazon.com/images/I/41sMT4+xUZL._AC_.jpg
# Index in DB: 58005
# Processed 57226/98662: https://m.media-amazon.com/images/I/61vSrfzpaQL._AC_.jpg
# Index in DB: 58006
# Processed 57227/98662: https://m.media-amazon.com/images/I/31JNebpA7oL._AC_.jpg
# Index in DB: 58007
# Processed 57228/98662: https://m.media-amazon.com/images/I/41z0XcTnszL._AC_.jpg
# Index in DB: 58008
# Processed 57229/98662: https://m.media-amazon.com/images/I/31N2bMBayEL._AC_.jpg
# Index in DB: 58009
# Processed 57230/98662: https://m.media-amazon.com/images/I/519EXMVsOPL._AC_.jpg
# Index in DB: 58010
# Processed 57231/98662: https://m.media-amazon.com/images/I/41gQMtg-pDL._AC_.jpg
# Index in DB: 58011
# Processed 57232/98662: https://m.media-amazon.com/images/I/51gFwAcgeGL._AC_.jpg
# Index in DB: 58012
# Processed 57233/98662: https://m.media-amazon.com/images/I/41W51FF8MEL._AC_.jpg
# Index in DB: 58013
# Processed 57234/98662: https://m.media-amazon.com/images/I/41UUDHDleeL._AC_.jpg
# Index in DB: 58014
# Processed 57235/98662: https://m.media-amazon.com/images/I/41B44-N-KQL._AC_.jpg
# Index in DB: 58015
# Processed 57236/98662: https://m.media-amazon.com/images/I/51CDeSWF8vL._AC_.jpg
# Index in DB: 58016
# Processed 57237/98662: https://m.media-amazon.com/images/I/41ty22dGQRL._AC_.jpg
# Index in DB: 58017
# Processed 57238/98662: https://m.media-amazon.com/images/I/31+ycRGuwjL._AC_.jpg
# Index in DB: 58018
# Processed 57239/98662: https://m.media-amazon.com/images/I/51p56RHdJmL._AC_.jpg
# Index in DB: 58019
# Processed 57240/98662: https://m.media-amazon.com/images/I/41CYkhdWSGL._AC_.jpg
# Index in DB: 58020
# Processed 57241/98662: https://m.media-amazon.com/images/I/31fLKxjy5EL._AC_.jpg
# Index in DB: 58021
# Processed 57242/98662: https://m.media-amazon.com/images/I/51TGD7d8FaL._AC_.jpg
# Index in DB: 58022
# Processed 57243/98662: https://m.media-amazon.com/images/I/51Egp+dR3oL._AC_.jpg
# Index in DB: 58023
# Processed 57244/98662: https://m.media-amazon.com/images/I/51OI1FteQGL._AC_.jpg
# Index in DB: 58024
# Processed 57245/98662: https://m.media-amazon.com/images/I/41GloDCjTPL._AC_.jpg
# Index in DB: 58025
# Processed 57246/98662: https://m.media-amazon.com/images/I/51DBlYCn7PL._AC_.jpg
# Index in DB: 58026
# Processed 57247/98662: https://m.media-amazon.com/images/I/41pB67xuRcL._AC_.jpg
# Index in DB: 58027
# Processed 57248/98662: https://m.media-amazon.com/images/I/51IeYJAyokL._AC_.jpg
# Index in DB: 58028
# Processed 57249/98662: https://m.media-amazon.com/images/I/318+MJn0BgL._AC_.jpg
# Index in DB: 58029
# Processed 57250/98662: https://m.media-amazon.com/images/I/41eP5Fc8wvL._AC_.jpg
# Index in DB: 58030
# Processed 57251/98662: https://m.media-amazon.com/images/I/31j0qiNWR0L._AC_.jpg
# Index in DB: 58031
# Processed 57252/98662: https://m.media-amazon.com/images/I/41rw-IU86YL._AC_.jpg
# Index in DB: 58032
# Processed 57253/98662: https://m.media-amazon.com/images/I/31Eihuhn9NL._AC_.jpg
# Index in DB: 58033
# Processed 57254/98662: https://m.media-amazon.com/images/I/51zliWiFeKL._AC_.jpg
# Index in DB: 58034
# Processed 57255/98662: https://m.media-amazon.com/images/I/317IOxGVCVL._AC_.jpg
# Index in DB: 58035
# Processed 57256/98662: https://m.media-amazon.com/images/I/318xFuFPTSL._AC_.jpg
# Index in DB: 58036
# Processed 57257/98662: https://m.media-amazon.com/images/I/310hKgd815L._AC_.jpg
# Index in DB: 58037
# Processed 57258/98662: https://m.media-amazon.com/images/I/316OU7n6UPL._AC_.jpg
# Index in DB: 58038
# Processed 57259/98662: https://m.media-amazon.com/images/I/41fReBJV+dL._AC_.jpg
# Index in DB: 58039
# Processed 57260/98662: https://m.media-amazon.com/images/I/51308Fu+j8L._AC_.jpg
# Index in DB: 58040
# Processed 57261/98662: https://m.media-amazon.com/images/I/51KEtaXaVXL._AC_.jpg
# Index in DB: 58041
# Processed 57262/98662: https://m.media-amazon.com/images/I/41pvcsineyL._AC_.jpg
# Index in DB: 58042
# Processed 57263/98662: https://m.media-amazon.com/images/I/41djFc-39XL._AC_.jpg
# Index in DB: 58043
# Processed 57264/98662: https://m.media-amazon.com/images/I/51zwEB9ZJZL._AC_.jpg
# Index in DB: 58044
# Processed 57265/98662: https://m.media-amazon.com/images/I/61yz8uV5dJL._AC_.jpg
# Index in DB: 58045
# Processed 57266/98662: https://m.media-amazon.com/images/I/41eJ29zIY+L._AC_.jpg
# Index in DB: 58046
# Processed 57267/98662: https://m.media-amazon.com/images/I/41CZtvlTdIL._AC_.jpg
# Index in DB: 58047
# Processed 57268/98662: https://m.media-amazon.com/images/I/41Iu3+5qibL._AC_.jpg
# Index in DB: 58048
# Processed 57269/98662: https://m.media-amazon.com/images/I/41OaRevDk6L._AC_.jpg
# Index in DB: 58049
# Processed 57270/98662: https://m.media-amazon.com/images/I/31ETw8TIuLL._AC_.jpg
# Index in DB: 58050
# Processed 57271/98662: https://m.media-amazon.com/images/I/51YZr0iWPpL._AC_.jpg
# Index in DB: 58051
# Processed 57272/98662: https://m.media-amazon.com/images/I/414w28W2Q2L._AC_.jpg
# Index in DB: 58052
# Processed 57273/98662: https://m.media-amazon.com/images/I/51GKB2AUncL._AC_.jpg
# Index in DB: 58053
# Processed 57274/98662: https://m.media-amazon.com/images/I/31VszpMfXNL._AC_.jpg
# Index in DB: 58054
# Processed 57275/98662: https://m.media-amazon.com/images/I/41k5wAhtv-L._AC_.jpg
# Index in DB: 58055
# Processed 57276/98662: https://m.media-amazon.com/images/I/415iovzUUEL._AC_.jpg
# Index in DB: 58056
# Processed 57277/98662: https://m.media-amazon.com/images/I/41f0LJoeKYL._AC_.jpg
# Index in DB: 58057
# Processed 57278/98662: https://m.media-amazon.com/images/I/31itTP4yV-L._AC_.jpg
# Index in DB: 58058
# Processed 57279/98662: https://m.media-amazon.com/images/I/51tCmarnO9L._AC_.jpg
# Index in DB: 58059
# Processed 57280/98662: https://m.media-amazon.com/images/I/41WDexbg7cL._AC_.jpg
# Index in DB: 58060
# Processed 57281/98662: https://m.media-amazon.com/images/I/51eHxX2lJJL._AC_.jpg
# Index in DB: 58061
# Processed 57282/98662: https://m.media-amazon.com/images/I/31gyh3GVRWS._AC_.jpg
# Index in DB: 58062
# Processed 57283/98662: https://m.media-amazon.com/images/I/61xL4LPl6pL._AC_.jpg
# Index in DB: 58063
# Processed 57284/98662: https://m.media-amazon.com/images/I/41dVjLN277L._AC_.jpg
# Index in DB: 58064
# Processed 57285/98662: https://m.media-amazon.com/images/I/51fRSN5OowL._AC_.jpg
# Index in DB: 58065
# Processed 57286/98662: https://m.media-amazon.com/images/I/41ouZxj6iaL._AC_.jpg
# Index in DB: 58066
# Processed 57287/98662: https://m.media-amazon.com/images/I/41zPgQGzHTL._AC_.jpg
# Index in DB: 58067
# Processed 57288/98662: https://m.media-amazon.com/images/I/41Oi4OzNgVL._AC_.jpg
# Index in DB: 58068
# Processed 57289/98662: https://m.media-amazon.com/images/I/41b82iYypQL._AC_.jpg
# Index in DB: 58069
# Processed 57290/98662: https://m.media-amazon.com/images/I/4197FgkpztL._AC_.jpg
# Index in DB: 58070
# Processed 57291/98662: https://m.media-amazon.com/images/I/514FPSYL+fL._AC_.jpg
# Index in DB: 58071
# Processed 57292/98662: https://m.media-amazon.com/images/I/31RgP4HsBpL._AC_.jpg
# Index in DB: 58072
# Processed 57293/98662: https://m.media-amazon.com/images/I/41G-NmEHIQL._AC_.jpg
# Index in DB: 58073
# Processed 57294/98662: https://m.media-amazon.com/images/I/61VaPW2qKZL._AC_.jpg
# Index in DB: 58074
# Processed 57295/98662: https://m.media-amazon.com/images/I/31Xqhnk6TlL._AC_.jpg
# Index in DB: 58075
# Processed 57296/98662: https://m.media-amazon.com/images/I/31-rb8IOfBL._AC_.jpg
# Index in DB: 58076
# Processed 57297/98662: https://m.media-amazon.com/images/I/51AXsSuiQML._AC_.jpg
# Index in DB: 58077
# Processed 57298/98662: https://m.media-amazon.com/images/I/41ktuGB3L2L._AC_.jpg
# Index in DB: 58078
# Processed 57299/98662: https://m.media-amazon.com/images/I/41UjUNavCFL._AC_.jpg
# Index in DB: 58079
# Processed 57300/98662: https://m.media-amazon.com/images/I/413PK1js9yL._AC_.jpg
# Index in DB: 58080
# Processed 57301/98662: https://m.media-amazon.com/images/I/41yEC3C1JsL._AC_.jpg
# Index in DB: 58081
# Processed 57302/98662: https://m.media-amazon.com/images/I/411AjjuwuqL._AC_.jpg
# Index in DB: 58082
# Processed 57303/98662: https://m.media-amazon.com/images/I/31U+C-4PczL._AC_.jpg
# Index in DB: 58083
# Processed 57304/98662: https://m.media-amazon.com/images/I/41EVMEuLtxL._AC_.jpg
# Index in DB: 58084
# Processed 57305/98662: https://m.media-amazon.com/images/I/41vjZIw1qhL._AC_.jpg
# Index in DB: 58085
# Processed 57306/98662: https://m.media-amazon.com/images/I/4168ioCpH7L._AC_.jpg
# Index in DB: 58086
# Processed 57307/98662: https://m.media-amazon.com/images/I/41LV-cTEWjL._AC_.jpg
# Index in DB: 58087
# Processed 57308/98662: https://m.media-amazon.com/images/I/515KDXZV7zL._AC_.jpg
# Index in DB: 58088
# Processed 57309/98662: https://m.media-amazon.com/images/I/41j9cBobVfL._AC_.jpg
# Index in DB: 58089
# Processed 57310/98662: https://m.media-amazon.com/images/I/41nVhArtf+L._AC_.jpg
# Index in DB: 58090
# Processed 57311/98662: https://m.media-amazon.com/images/I/41Hh0BQXclL._AC_.jpg
# Index in DB: 58091
# Processed 57312/98662: https://m.media-amazon.com/images/I/31kqoTqvwML._AC_.jpg
# Index in DB: 58092
# Processed 57313/98662: https://m.media-amazon.com/images/I/41Rj8Sq+D4L._AC_.jpg
# Index in DB: 58093
# Processed 57314/98662: https://m.media-amazon.com/images/I/417geN8oslL._AC_.jpg
# Index in DB: 58094
# Processed 57315/98662: https://m.media-amazon.com/images/I/31LTwxjTGIL._AC_.jpg
# Index in DB: 58095
# Processed 57316/98662: https://m.media-amazon.com/images/I/41YyVI3KbvL._AC_.jpg
# Index in DB: 58096
# Processed 57317/98662: https://m.media-amazon.com/images/I/51-4YEQChJL._AC_.jpg
# Index in DB: 58097
# Processed 57318/98662: https://m.media-amazon.com/images/I/51EwmRswCgL._AC_.jpg
# Index in DB: 58098
# Processed 57319/98662: https://m.media-amazon.com/images/I/315fjX0uT7L._AC_.jpg
# Index in DB: 58099
# Processed 57320/98662: https://m.media-amazon.com/images/I/518+aZOtFVL._AC_.jpg
# Index in DB: 58100
# Processed 57321/98662: https://m.media-amazon.com/images/I/41vGA-fQ86L._AC_.jpg
# Index in DB: 58101
# Processed 57322/98662: https://m.media-amazon.com/images/I/41xCF6shkvL._AC_.jpg
# Index in DB: 58102
# Processed 57323/98662: https://m.media-amazon.com/images/I/51GPY9cexeL._AC_.jpg
# Index in DB: 58103
# Processed 57324/98662: https://m.media-amazon.com/images/I/41W6vzwbS2L._AC_.jpg
# Index in DB: 58104
# Processed 57325/98662: https://m.media-amazon.com/images/I/51xdPajij0L._AC_.jpg
# Index in DB: 58105
# Processed 57326/98662: https://m.media-amazon.com/images/I/31lRPXolAnL._AC_.jpg
# Index in DB: 58106
# Processed 57327/98662: https://m.media-amazon.com/images/I/41hciTezUVL._AC_.jpg
# Index in DB: 58107
# Processed 57328/98662: https://m.media-amazon.com/images/I/413+AF65+1L._AC_.jpg
# Index in DB: 58108
# Processed 57329/98662: https://m.media-amazon.com/images/I/310cv1PapnL._AC_.jpg
# Index in DB: 58109
# Processed 57330/98662: https://m.media-amazon.com/images/I/3164U-waX5L._AC_.jpg
# Index in DB: 58110
# Processed 57331/98662: https://m.media-amazon.com/images/I/41dtbFgg7FL._AC_.jpg
# Index in DB: 58111
# Processed 57332/98662: https://m.media-amazon.com/images/I/31mXrWBWGIL._AC_.jpg
# Index in DB: 58112
# Processed 57333/98662: https://m.media-amazon.com/images/I/519r9Cj0BVL._AC_.jpg
# Index in DB: 58113
# Processed 57334/98662: https://m.media-amazon.com/images/I/51Iopy-+PeL._AC_.jpg
# Index in DB: 58114
# Processed 57335/98662: https://m.media-amazon.com/images/I/51Wko2WQPDL._AC_.jpg
# Index in DB: 58115
# Processed 57336/98662: https://m.media-amazon.com/images/I/310BQ9j4J9L._AC_.jpg
# Index in DB: 58116
# Processed 57337/98662: https://m.media-amazon.com/images/I/41xJHT09-ML._AC_.jpg
# Index in DB: 58117
# Processed 57338/98662: https://m.media-amazon.com/images/I/31kdQwXk2wL._AC_.jpg
# Index in DB: 58118
# Processed 57339/98662: https://m.media-amazon.com/images/I/51ZEGih1ijL._AC_.jpg
# Index in DB: 58119
# Processed 57340/98662: https://m.media-amazon.com/images/I/41riGDELpML._AC_.jpg
# Index in DB: 58120
# Processed 57341/98662: https://m.media-amazon.com/images/I/51PEMCvxV1L._AC_.jpg
# Index in DB: 58121
# Processed 57342/98662: https://m.media-amazon.com/images/I/51GDHmAWpGL._AC_.jpg
# Index in DB: 58122
# Processed 57343/98662: https://m.media-amazon.com/images/I/41SsWY0V2DL._AC_.jpg
# Index in DB: 58123
# Processed 57344/98662: https://m.media-amazon.com/images/I/51Nx7LSeXCL._AC_.jpg
# Index in DB: 58124
# Processed 57345/98662: https://m.media-amazon.com/images/I/31uN4pnP5ML._AC_.jpg
# Index in DB: 58125
# Processed 57346/98662: https://m.media-amazon.com/images/I/31ehaghUPxL._AC_.jpg
# Index in DB: 58126
# Processed 57347/98662: https://m.media-amazon.com/images/I/41c1R2PQTaL._AC_.jpg
# Index in DB: 58127
# Processed 57348/98662: https://m.media-amazon.com/images/I/31Ssh7N1sRL._AC_.jpg
# Index in DB: 58129
# Processed 57349/98662: https://m.media-amazon.com/images/I/41Bam2cgnOL._AC_.jpg
# Index in DB: 58130
# Processed 57350/98662: https://m.media-amazon.com/images/I/41Q5VwuYjkL._AC_.jpg
# Index in DB: 58131
# Processed 57351/98662: https://m.media-amazon.com/images/I/31F4BnAI-LL._AC_.jpg
# Index in DB: 58132
# Processed 57352/98662: https://m.media-amazon.com/images/I/41U0xWwbOsL._AC_.jpg
# Index in DB: 58133
# Processed 57353/98662: https://m.media-amazon.com/images/I/41V3n4l5CtL._AC_.jpg
# Index in DB: 58134
# Processed 57354/98662: https://m.media-amazon.com/images/I/51XS5GQJiRL._AC_.jpg
# Index in DB: 58135
# Processed 57355/98662: https://m.media-amazon.com/images/I/21TNa7KIAEL._AC_.jpg
# Index in DB: 58136
# Processed 57356/98662: https://m.media-amazon.com/images/I/51mb0C2zm8L._AC_.jpg
# Index in DB: 58137
# Processed 57357/98662: https://m.media-amazon.com/images/I/41awOo7MzlL._AC_.jpg
# Index in DB: 58138
# Processed 57358/98662: https://m.media-amazon.com/images/I/41J-uYj-lPL._AC_.jpg
# Index in DB: 58139
# Processed 57359/98662: https://m.media-amazon.com/images/I/41b644tv37L._AC_.jpg
# Index in DB: 58140
# Processed 57360/98662: https://m.media-amazon.com/images/I/51c9we4+ZsL._AC_.jpg
# Index in DB: 58141
# Processed 57361/98662: https://m.media-amazon.com/images/I/3123HgjM56L._AC_.jpg
# Index in DB: 58142
# Processed 57362/98662: https://m.media-amazon.com/images/I/41s-8em2f7L._AC_.jpg
# Index in DB: 58143
# Processed 57363/98662: https://m.media-amazon.com/images/I/51nFqXZ5iDL._AC_.jpg
# Index in DB: 58144
# Processed 57364/98662: https://m.media-amazon.com/images/I/41abJ7TVxlL._AC_.jpg
# Index in DB: 58145
# Processed 57365/98662: https://m.media-amazon.com/images/I/31tlxbxgp7L._AC_.jpg
# Index in DB: 58146
# Processed 57366/98662: https://m.media-amazon.com/images/I/31hoPuDxCbL._AC_.jpg
# Index in DB: 58147
# Processed 57367/98662: https://m.media-amazon.com/images/I/31Uzo7HMvqL._AC_.jpg
# Index in DB: 58148
# Processed 57368/98662: https://m.media-amazon.com/images/I/417kLfDl3TL._AC_.jpg
# Index in DB: 58149
# Processed 57369/98662: https://m.media-amazon.com/images/I/317tcACXpFL._AC_.jpg
# Index in DB: 58150
# Processed 57370/98662: https://m.media-amazon.com/images/I/41iOHbt4LIL._AC_.jpg
# Index in DB: 58151
# Processed 57371/98662: https://m.media-amazon.com/images/I/41SSxVbxSxL._AC_.jpg
# Index in DB: 58152
# Processed 57372/98662: https://m.media-amazon.com/images/I/51out9ZGiQL._AC_.jpg
# Index in DB: 58153
# Processed 57373/98662: https://m.media-amazon.com/images/I/31Bv285EsqL._AC_.jpg
# Index in DB: 58154
# Processed 57374/98662: https://m.media-amazon.com/images/I/31KRAUALh+S._AC_.jpg
# Index in DB: 58155
# Processed 57375/98662: https://m.media-amazon.com/images/I/51Oa-2TOnNL._AC_.jpg
# Index in DB: 58156
# Processed 57376/98662: https://m.media-amazon.com/images/I/41Fr4rH5yzL._AC_.jpg
# Index in DB: 58157
# Processed 57377/98662: https://m.media-amazon.com/images/I/41i6J+981kL._AC_.jpg
# Index in DB: 58158
# Processed 57378/98662: https://m.media-amazon.com/images/I/41hBYMz90fL._AC_.jpg
# Index in DB: 58159
# Processed 57379/98662: https://m.media-amazon.com/images/I/41YwU9ClYPL._AC_.jpg
# Index in DB: 58160
# Processed 57380/98662: https://m.media-amazon.com/images/I/41-gtSbKSmL._AC_.jpg
# Index in DB: 58161
# Processed 57381/98662: https://m.media-amazon.com/images/I/41VZe0BvXdL._AC_.jpg
# Index in DB: 58163
# Processed 57382/98662: https://m.media-amazon.com/images/I/31R3uCM5UbL._AC_.jpg
# Index in DB: 58164
# Processed 57383/98662: https://m.media-amazon.com/images/I/31p11x13mNL._AC_.jpg
# Index in DB: 58165
# Processed 57384/98662: https://m.media-amazon.com/images/I/31h+SQSm64L._AC_.jpg
# Index in DB: 58166
# Processed 57385/98662: https://m.media-amazon.com/images/I/5148JoN-LDL._AC_.jpg
# Index in DB: 58167
# Processed 57386/98662: https://m.media-amazon.com/images/I/31C+UudMlIL._AC_.jpg
# Index in DB: 58168
# Processed 57387/98662: https://m.media-amazon.com/images/I/41X7X7HAFAL._AC_.jpg
# Index in DB: 58169
# Processed 57388/98662: https://m.media-amazon.com/images/I/51jwk5u51+S._AC_.jpg
# Index in DB: 58170
# Processed 57389/98662: https://m.media-amazon.com/images/I/41v1rG1d8lL._AC_.jpg
# Index in DB: 58171
# Processed 57390/98662: https://m.media-amazon.com/images/I/41UATIG6xNL._AC_.jpg
# Index in DB: 58172
# Processed 57391/98662: https://m.media-amazon.com/images/I/41WJs4S3npL._AC_.jpg
# Index in DB: 58173
# Processed 57392/98662: https://m.media-amazon.com/images/I/310dvpyRnyL._AC_.jpg
# Index in DB: 58174
# Processed 57393/98662: https://m.media-amazon.com/images/I/51QhUoXrg5S._AC_.jpg
# Index in DB: 58175
# Processed 57394/98662: https://m.media-amazon.com/images/I/512TxpTQ4oL._AC_.jpg
# Index in DB: 58176
# Processed 57395/98662: https://m.media-amazon.com/images/I/41xE1XgDCPL._AC_.jpg
# Index in DB: 58177
# Processed 57396/98662: https://m.media-amazon.com/images/I/51GL7WtGp4L._AC_.jpg
# Index in DB: 58178
# Processed 57397/98662: https://m.media-amazon.com/images/I/41ZDKOicm7L._AC_.jpg
# Index in DB: 58179
# Processed 57398/98662: https://m.media-amazon.com/images/I/51vRsBtgquL._AC_.jpg
# Index in DB: 58180
# Processed 57399/98662: https://m.media-amazon.com/images/I/51DNEx4cA+L._AC_.jpg
# Index in DB: 58181
# Processed 57400/98662: https://m.media-amazon.com/images/I/31KFdX-ATbL._AC_.jpg
# Index in DB: 58182
# Processed 57401/98662: https://m.media-amazon.com/images/I/41oUwTvSG5L._AC_.jpg
# Index in DB: 58183
# Processed 57402/98662: https://m.media-amazon.com/images/I/31GCxWHuWiL._AC_.jpg
# Index in DB: 58184
# Processed 57403/98662: https://m.media-amazon.com/images/I/41t9wPEuyxL._AC_.jpg
# Index in DB: 58185
# Processed 57404/98662: https://m.media-amazon.com/images/I/41Or31p90JL._AC_.jpg
# Index in DB: 58186
# Processed 57405/98662: https://m.media-amazon.com/images/I/51FtOsVwx7L._AC_.jpg
# Index in DB: 58187
# Processed 57406/98662: https://m.media-amazon.com/images/I/31+zU4lpFNL._AC_.jpg
# Index in DB: 58188
# Processed 57407/98662: https://m.media-amazon.com/images/I/41dYRLOwhtL._AC_.jpg
# Index in DB: 58189
# Processed 57408/98662: https://m.media-amazon.com/images/I/41rXIBwAdML._AC_.jpg
# Index in DB: 58190
# Processed 57409/98662: https://m.media-amazon.com/images/I/41E20lVtPHL._AC_.jpg
# Index in DB: 58191
# Processed 57410/98662: https://m.media-amazon.com/images/I/31VqHZEp+zL._AC_.jpg
# Index in DB: 58192
# Processed 57411/98662: https://m.media-amazon.com/images/I/41OGzXExnmL._AC_.jpg
# Index in DB: 58193
# Processed 57412/98662: https://m.media-amazon.com/images/I/41-uyyClBmL._AC_.jpg
# Index in DB: 58194
# Processed 57413/98662: https://m.media-amazon.com/images/I/41hy+1HxSCL._AC_.jpg
# Index in DB: 58195
# Processed 57414/98662: https://m.media-amazon.com/images/I/51ux5zx-XzL._AC_.jpg
# Index in DB: 58196
# Processed 57415/98662: https://m.media-amazon.com/images/I/31wN2eQmgoL._AC_.jpg
# Index in DB: 58197
# Processed 57416/98662: https://m.media-amazon.com/images/I/41i-wgreL0L._AC_.jpg
# Index in DB: 58198
# Processed 57417/98662: https://m.media-amazon.com/images/I/41g-oZAtXML._AC_.jpg
# Index in DB: 58199
# Processed 57418/98662: https://m.media-amazon.com/images/I/31taHR5UrnL._AC_.jpg
# Index in DB: 58200
# Processed 57419/98662: https://m.media-amazon.com/images/I/31SGgxJMfQL._AC_.jpg
# Index in DB: 58201
# Processed 57420/98662: https://m.media-amazon.com/images/I/41Qt1om2csS._AC_.jpg
# Index in DB: 58202
# Processed 57421/98662: https://m.media-amazon.com/images/I/41-fljfNGTL._AC_.jpg
# Index in DB: 58203
# Processed 57422/98662: https://m.media-amazon.com/images/I/51V1SbVRGHL._AC_.jpg
# Index in DB: 58204
# Processed 57423/98662: https://m.media-amazon.com/images/I/31WdHephZOS._AC_.jpg
# Index in DB: 58205
# Processed 57424/98662: https://m.media-amazon.com/images/I/61Cy+QSCNgL._AC_.jpg
# Index in DB: 58206
# Processed 57425/98662: https://m.media-amazon.com/images/I/51rh0KCxXvL._AC_.jpg
# Index in DB: 58207
# Processed 57426/98662: https://m.media-amazon.com/images/I/51TEPPJZOCL._AC_.jpg
# Index in DB: 58208
# Processed 57427/98662: https://m.media-amazon.com/images/I/31QQs1huW7L._AC_.jpg
# Index in DB: 58209
# Processed 57428/98662: https://m.media-amazon.com/images/I/31DlMLpQHrL._AC_.jpg
# Index in DB: 58210
# Processed 57429/98662: https://m.media-amazon.com/images/I/41vT9CoNn2L._AC_.jpg
# Index in DB: 58211
# Processed 57430/98662: https://m.media-amazon.com/images/I/51e1UhQw6HL._AC_.jpg
# Index in DB: 58212
# Processed 57431/98662: https://m.media-amazon.com/images/I/31cvs9eg0qL._AC_.jpg
# Index in DB: 58213
# Processed 57432/98662: https://m.media-amazon.com/images/I/41bU5lH1rnL._AC_.jpg
# Index in DB: 58214
# Processed 57433/98662: https://m.media-amazon.com/images/I/51cMHBjV3LL._AC_.jpg
# Index in DB: 58216
# Processed 57434/98662: https://m.media-amazon.com/images/I/41SCEGWrhpL._AC_.jpg
# Index in DB: 58217
# Processed 57435/98662: https://m.media-amazon.com/images/I/41uZnMMR58L._AC_.jpg
# Index in DB: 58218
# Processed 57436/98662: https://m.media-amazon.com/images/I/311q0oNqnuL._AC_.jpg
# Index in DB: 58219
# Processed 57437/98662: https://m.media-amazon.com/images/I/51eqmixMaYL._AC_.jpg
# Index in DB: 58220
# Processed 57438/98662: https://m.media-amazon.com/images/I/41jgp7VF4KL._AC_.jpg
# Index in DB: 58221
# Processed 57439/98662: https://m.media-amazon.com/images/I/41zbQUCcFBL._AC_.jpg
# Index in DB: 58222
# Processed 57440/98662: https://m.media-amazon.com/images/I/51j1Cxuu-JL._AC_.jpg
# Index in DB: 58223
# Processed 57441/98662: https://m.media-amazon.com/images/I/51CwzpKhDeL._AC_.jpg
# Index in DB: 58224
# Processed 57442/98662: https://m.media-amazon.com/images/I/31xkLFiTKyL._AC_.jpg
# Index in DB: 58226
# Processed 57443/98662: https://m.media-amazon.com/images/I/41CFjZ9lO0L._AC_.jpg
# Index in DB: 58228
# Processed 57444/98662: https://m.media-amazon.com/images/I/41H+uvbIUCL._AC_.jpg
# Index in DB: 58229
# Processed 57445/98662: https://m.media-amazon.com/images/I/41NgNay6P9L._AC_.jpg
# Index in DB: 58230
# Processed 57446/98662: https://m.media-amazon.com/images/I/51i6PAG0VLL._AC_.jpg
# Index in DB: 58231
# Processed 57447/98662: https://m.media-amazon.com/images/I/41lLqWlgCLL._AC_.jpg
# Index in DB: 58232
# Processed 57448/98662: https://m.media-amazon.com/images/I/51+qvKbCinL._AC_.jpg
# Index in DB: 58233
# Processed 57449/98662: https://m.media-amazon.com/images/I/51T4UpzrZpL._AC_.jpg
# Index in DB: 58234
# Processed 57450/98662: https://m.media-amazon.com/images/I/51ev-p1qt4L._AC_.jpg
# Index in DB: 58235
# Processed 57451/98662: https://m.media-amazon.com/images/I/317KHdec2KL._AC_.jpg
# Index in DB: 58236
# Processed 57452/98662: https://m.media-amazon.com/images/I/51lLtimtroL._AC_.jpg
# Index in DB: 58237
# Processed 57453/98662: https://m.media-amazon.com/images/I/31X9+mOeQJL._AC_.jpg
# Index in DB: 58238
# Processed 57454/98662: https://m.media-amazon.com/images/I/41p4dk19b0L._AC_.jpg
# Index in DB: 58239
# Processed 57455/98662: https://m.media-amazon.com/images/I/51qxNtToQvL._AC_.jpg
# Index in DB: 58240
# Processed 57456/98662: https://m.media-amazon.com/images/I/41DZm8v1UeL._AC_.jpg
# Index in DB: 58241
# Processed 57457/98662: https://m.media-amazon.com/images/I/41yYxn+kneS._AC_.jpg
# Index in DB: 58243
# Processed 57458/98662: https://m.media-amazon.com/images/I/51n2sWDBOqL._AC_.jpg
# Index in DB: 58244
# Processed 57459/98662: https://m.media-amazon.com/images/I/51JXjHGiBPL._AC_.jpg
# Index in DB: 58245
# Processed 57460/98662: https://m.media-amazon.com/images/I/31ebltZXPHL._AC_.jpg
# Index in DB: 58246
# Processed 57461/98662: https://m.media-amazon.com/images/I/518vGIDp+XL._AC_.jpg
# Index in DB: 58247
# Processed 57462/98662: https://m.media-amazon.com/images/I/31kU8G7dwwL._AC_.jpg
# Index in DB: 58248
# Processed 57463/98662: https://m.media-amazon.com/images/I/516Tyfp++AL._AC_.jpg
# Index in DB: 58249
# Processed 57464/98662: https://m.media-amazon.com/images/I/51+2bgg2NEL._AC_.jpg
# Index in DB: 58250
# Processed 57465/98662: https://m.media-amazon.com/images/I/41Omul0rr5L._AC_.jpg
# Index in DB: 58251
# Processed 57466/98662: https://m.media-amazon.com/images/I/519CWU5iYvL._AC_.jpg
# Index in DB: 58252
# Processed 57467/98662: https://m.media-amazon.com/images/I/41S4fI1O--L._AC_.jpg
# Index in DB: 58253
# Processed 57468/98662: https://m.media-amazon.com/images/I/51UnKeWmzCL._AC_.jpg
# Index in DB: 58254
# Processed 57469/98662: https://m.media-amazon.com/images/I/51ZXPkC1e8L._AC_.jpg
# Index in DB: 58255
# Processed 57470/98662: https://m.media-amazon.com/images/I/51lBzL1dQ1L._AC_.jpg
# Index in DB: 58256
# Processed 57471/98662: https://m.media-amazon.com/images/I/51MPd3yckzL._AC_.jpg
# Index in DB: 58257
# Processed 57472/98662: https://m.media-amazon.com/images/I/51Ldo7EXPPL._AC_.jpg
# Index in DB: 58258
# Processed 57473/98662: https://m.media-amazon.com/images/I/41FO0A0JpmL._AC_.jpg
# Index in DB: 58259
# Processed 57474/98662: https://m.media-amazon.com/images/I/41tx+V9x38L._AC_.jpg
# Index in DB: 58260
# Processed 57475/98662: https://m.media-amazon.com/images/I/31f6YeKm1oL._AC_.jpg
# Index in DB: 58261
# Processed 57476/98662: https://m.media-amazon.com/images/I/51+eQczuC7L._AC_.jpg
# Index in DB: 58262
# Processed 57477/98662: https://m.media-amazon.com/images/I/31SqrGdYbCL._AC_.jpg
# Index in DB: 58263
# Processed 57478/98662: https://m.media-amazon.com/images/I/41XLObX3UjL._AC_.jpg
# Index in DB: 58264
# Processed 57479/98662: https://m.media-amazon.com/images/I/51o0zSNIEPL._AC_.jpg
# Index in DB: 58265
# Processed 57480/98662: https://m.media-amazon.com/images/I/517UUDIV1lL._AC_.jpg
# Index in DB: 58266
# Processed 57481/98662: https://m.media-amazon.com/images/I/41-HNS+lEDL._AC_.jpg
# Index in DB: 58267
# Processed 57482/98662: https://m.media-amazon.com/images/I/516HOJonvJL._AC_.jpg
# Index in DB: 58268
# Processed 57483/98662: https://m.media-amazon.com/images/I/412eElIc5iL._AC_.jpg
# Index in DB: 58269
# Processed 57484/98662: https://m.media-amazon.com/images/I/31CVxjW6ZkL._AC_.jpg
# Index in DB: 58270
# Processed 57485/98662: https://m.media-amazon.com/images/I/41wfby6NLLL._AC_.jpg
# Index in DB: 58271
# Processed 57486/98662: https://m.media-amazon.com/images/I/31Uk2mVQ7OL._AC_.jpg
# Index in DB: 58272
# Processed 57487/98662: https://m.media-amazon.com/images/I/41HZa1eLh9L._AC_.jpg
# Index in DB: 58273
# Processed 57488/98662: https://m.media-amazon.com/images/I/41yImQ1vseL._AC_.jpg
# Index in DB: 58274
# Processed 57489/98662: https://m.media-amazon.com/images/I/41irrSG7lQL._AC_.jpg
# Index in DB: 58275
# Processed 57490/98662: https://m.media-amazon.com/images/I/41UiS1YfzvL._AC_.jpg
# Index in DB: 58276
# Processed 57491/98662: https://m.media-amazon.com/images/I/41pN4gSyglL._AC_.jpg
# Index in DB: 58277
# Processed 57492/98662: https://m.media-amazon.com/images/I/41xROpvLw+L._AC_.jpg
# Index in DB: 58278
# Processed 57493/98662: https://m.media-amazon.com/images/I/517RvwuOm4L._AC_.jpg
# Index in DB: 58279
# Processed 57494/98662: https://m.media-amazon.com/images/I/41zzsnfknZL._AC_.jpg
# Index in DB: 58280
# Processed 57495/98662: https://m.media-amazon.com/images/I/31-eZVM2rHL._AC_.jpg
# Index in DB: 58281
# Processed 57496/98662: https://m.media-amazon.com/images/I/51qBReLq-PL._AC_.jpg
# Index in DB: 58282
# Processed 57497/98662: https://m.media-amazon.com/images/I/41ZOYnghzKL._AC_.jpg
# Index in DB: 58283
# Processed 57498/98662: https://m.media-amazon.com/images/I/51KHjzQb3fL._AC_.jpg
# Index in DB: 58284
# Processed 57499/98662: https://m.media-amazon.com/images/I/517QXEu9WPL._AC_.jpg
# Index in DB: 58285
# Processed 57500/98662: https://m.media-amazon.com/images/I/31YSFwU4hXL._AC_.jpg
# Index in DB: 58286
# Processed 57501/98662: https://m.media-amazon.com/images/I/41mrOERwZuL._AC_.jpg
# Index in DB: 58287
# Processed 57502/98662: https://m.media-amazon.com/images/I/51Bv47Oa9tL._AC_.jpg
# Index in DB: 58288
# Processed 57503/98662: https://m.media-amazon.com/images/I/41b2N8jlRoL._AC_.jpg
# Index in DB: 58289
# Processed 57504/98662: https://m.media-amazon.com/images/I/51GSy1Ty5RL._AC_.jpg
# Index in DB: 58290
# Processed 57505/98662: https://m.media-amazon.com/images/I/51iJO0bSCPL._AC_.jpg
# Index in DB: 58291
# Processed 57506/98662: https://m.media-amazon.com/images/I/41CrZPPxc7L._AC_.jpg
# Index in DB: 58292
# Processed 57507/98662: https://m.media-amazon.com/images/I/41GxTAQX5YL._AC_.jpg
# Index in DB: 58293
# Processed 57508/98662: https://m.media-amazon.com/images/I/51iDjr-y7fL._AC_.jpg
# Index in DB: 58294
# Processed 57509/98662: https://m.media-amazon.com/images/I/41qdl6dg5cL._AC_.jpg
# Index in DB: 58295
# Processed 57510/98662: https://m.media-amazon.com/images/I/51N8YQPg7iL._AC_.jpg
# Index in DB: 58296
# Processed 57511/98662: https://m.media-amazon.com/images/I/318wF7sdoIL._AC_.jpg
# Index in DB: 58297
# Processed 57512/98662: https://m.media-amazon.com/images/I/21raWI8PTsL._AC_.jpg
# Index in DB: 58298
# Processed 57513/98662: https://m.media-amazon.com/images/I/41FdDX6TjGL._AC_.jpg
# Index in DB: 58299
# Processed 57514/98662: https://m.media-amazon.com/images/I/31WglAFq60L._AC_.jpg
# Index in DB: 58300
# Processed 57515/98662: https://m.media-amazon.com/images/I/41Xqg1IeAcL._AC_.jpg
# Index in DB: 58301
# Processed 57516/98662: https://m.media-amazon.com/images/I/41nc5aY9YuL._AC_.jpg
# Index in DB: 58302
# Processed 57517/98662: https://m.media-amazon.com/images/I/51sQM1OyGTL._AC_.jpg
# Index in DB: 58303
# Processed 57518/98662: https://m.media-amazon.com/images/I/41wZQ5Zm6mL._AC_.jpg
# Index in DB: 58304
# Processed 57519/98662: https://m.media-amazon.com/images/I/41aawprxthS._AC_.jpg
# Index in DB: 58305
# Processed 57520/98662: https://m.media-amazon.com/images/I/41l1kZHY63L._AC_.jpg
# Index in DB: 58306
# Processed 57521/98662: https://m.media-amazon.com/images/I/51iDTWktDlL._AC_.jpg
# Index in DB: 58307
# Processed 57522/98662: https://m.media-amazon.com/images/I/41buVpfooZL._AC_.jpg
# Index in DB: 58308
# Processed 57523/98662: https://m.media-amazon.com/images/I/41xLzct9L2L._AC_.jpg
# Index in DB: 58309
# Processed 57524/98662: https://m.media-amazon.com/images/I/41ODmpo4ApL._AC_.jpg
# Index in DB: 58310
# Processed 57525/98662: https://m.media-amazon.com/images/I/41Lv0ayWqJL._AC_.jpg
# Index in DB: 58311
# Processed 57526/98662: https://m.media-amazon.com/images/I/51h0c45BI+L._AC_.jpg
# Index in DB: 58312
# Processed 57527/98662: https://m.media-amazon.com/images/I/41dO3EQ+HJL._AC_.jpg
# Index in DB: 58313
# Processed 57528/98662: https://m.media-amazon.com/images/I/41SlxBfUVOS._AC_.jpg
# Index in DB: 58314
# Processed 57529/98662: https://m.media-amazon.com/images/I/41quJ2qm5GL._AC_.jpg
# Index in DB: 58315
# Processed 57530/98662: https://m.media-amazon.com/images/I/41CHm3MbJ9L._AC_.jpg
# Index in DB: 58316
# Processed 57531/98662: https://m.media-amazon.com/images/I/51jaln5MH4L._AC_.jpg
# Index in DB: 58317
# Processed 57532/98662: https://m.media-amazon.com/images/I/414VNKEo+fL._AC_.jpg
# Index in DB: 58318
# Processed 57533/98662: https://m.media-amazon.com/images/I/314XI41ybaS._AC_.jpg
# Index in DB: 58319
# Processed 57534/98662: https://m.media-amazon.com/images/I/41nRXMkOSKL._AC_.jpg
# Index in DB: 58320
# Processed 57535/98662: https://m.media-amazon.com/images/I/315G9gr55yL._AC_.jpg
# Index in DB: 58321
# Processed 57536/98662: https://m.media-amazon.com/images/I/41CF0Fg-vjL._AC_.jpg
# Index in DB: 58322
# Processed 57537/98662: https://m.media-amazon.com/images/I/419WzmmY7yL._AC_.jpg
# Index in DB: 58323
# Processed 57538/98662: https://m.media-amazon.com/images/I/31dlarVSQvL._AC_.jpg
# Index in DB: 58324
# Processed 57539/98662: https://m.media-amazon.com/images/I/41oIvw7yiPL._AC_.jpg
# Index in DB: 58325
# Processed 57540/98662: https://m.media-amazon.com/images/I/41rlGVV-uDL._AC_.jpg
# Index in DB: 58326
# Processed 57541/98662: https://m.media-amazon.com/images/I/41EZF4yAhyL._AC_.jpg
# Index in DB: 58327
# Processed 57542/98662: https://m.media-amazon.com/images/I/31nBaGEkdkL._AC_.jpg
# Index in DB: 58328
# Processed 57543/98662: https://m.media-amazon.com/images/I/41KHsjqPHmL._AC_.jpg
# Index in DB: 58329
# Processed 57544/98662: https://m.media-amazon.com/images/I/41uKtPYWauL._AC_.jpg
# Index in DB: 58330
# Processed 57545/98662: https://m.media-amazon.com/images/I/41K+BMhyzfL._AC_.jpg
# Index in DB: 58331
# Processed 57546/98662: https://m.media-amazon.com/images/I/31HXoY6Sw9L._AC_.jpg
# Index in DB: 58332
# Processed 57547/98662: https://m.media-amazon.com/images/I/31ZQmprPYLL._AC_.jpg
# Index in DB: 58333
# Processed 57548/98662: https://m.media-amazon.com/images/I/31vzGjBnotL._AC_.jpg
# Index in DB: 58334
# Processed 57549/98662: https://m.media-amazon.com/images/I/416Vv+XGI4L._AC_.jpg
# Index in DB: 58335
# Processed 57550/98662: https://m.media-amazon.com/images/I/318nWq7newL._AC_.jpg
# Index in DB: 58336
# Processed 57551/98662: https://m.media-amazon.com/images/I/41gH8DhiFhS._AC_.jpg
# Index in DB: 58337
# Processed 57552/98662: https://m.media-amazon.com/images/I/51EzZqNidIL._AC_.jpg
# Index in DB: 58338
# Processed 57553/98662: https://m.media-amazon.com/images/I/31697OmlKPL._AC_.jpg
# Index in DB: 58339
# Processed 57554/98662: https://m.media-amazon.com/images/I/31mHtWnk-OL._AC_.jpg
# Index in DB: 58340
# Processed 57555/98662: https://m.media-amazon.com/images/I/410TsH3OuWL._AC_.jpg
# Index in DB: 58341
# Processed 57556/98662: https://m.media-amazon.com/images/I/51HnA5qAmBL._AC_.jpg
# Index in DB: 58342
# Processed 57557/98662: https://m.media-amazon.com/images/I/417WSOYfXlL._AC_.jpg
# Index in DB: 58343
# Processed 57558/98662: https://m.media-amazon.com/images/I/41HMCD2LGeL._AC_.jpg
# Index in DB: 58344
# Processed 57559/98662: https://m.media-amazon.com/images/I/41chOoPzrtL._AC_.jpg
# Index in DB: 58345
# Processed 57560/98662: https://m.media-amazon.com/images/I/41zKAm8AyGL._AC_.jpg
# Index in DB: 58346
# Processed 57561/98662: https://m.media-amazon.com/images/I/51k-qFnGqPL._AC_.jpg
# Index in DB: 58347
# Processed 57562/98662: https://m.media-amazon.com/images/I/41W+SdiL1-L._AC_.jpg
# Index in DB: 58348
# Processed 57563/98662: https://m.media-amazon.com/images/I/41IutNIGRxL._AC_.jpg
# Index in DB: 58349
# Processed 57564/98662: https://m.media-amazon.com/images/I/51MrnAZNbvL._AC_.jpg
# Index in DB: 58350
# Processed 57565/98662: https://m.media-amazon.com/images/I/31BA9H5mvoS._AC_.jpg
# Index in DB: 58351
# Processed 57566/98662: https://m.media-amazon.com/images/I/41iKPGny2sL._AC_.jpg
# Index in DB: 58352
# Processed 57567/98662: https://m.media-amazon.com/images/I/416YQVs-wNL._AC_.jpg
# Index in DB: 58353
# Processed 57568/98662: https://m.media-amazon.com/images/I/41r9X3-8LNL._AC_.jpg
# Index in DB: 58354
# Processed 57569/98662: https://m.media-amazon.com/images/I/319y+pL1DxL._AC_.jpg
# Index in DB: 58355
# Processed 57570/98662: https://m.media-amazon.com/images/I/51PFuxMZU1L._AC_.jpg
# Index in DB: 58356
# Processed 57571/98662: https://m.media-amazon.com/images/I/41oqdElAc1L._AC_.jpg
# Index in DB: 58357
# Processed 57572/98662: https://m.media-amazon.com/images/I/31bzn+w6vgL._AC_.jpg
# Index in DB: 58358
# Processed 57573/98662: https://m.media-amazon.com/images/I/61BU2dJM7GL._AC_.jpg
# Index in DB: 58359
# Processed 57574/98662: https://m.media-amazon.com/images/I/41xL6DztT3L._AC_.jpg
# Index in DB: 58360
# Processed 57575/98662: https://m.media-amazon.com/images/I/41tnMMQME6L._AC_.jpg
# Index in DB: 58361
# Processed 57576/98662: https://m.media-amazon.com/images/I/41gH8G9-izL._AC_.jpg
# Index in DB: 58362
# Processed 57577/98662: https://m.media-amazon.com/images/I/61KcppepuiL._AC_.jpg
# Index in DB: 58363
# Processed 57578/98662: https://m.media-amazon.com/images/I/3150D+7v3xL._AC_.jpg
# Index in DB: 58364
# Processed 57579/98662: https://m.media-amazon.com/images/I/51zHxetJvAL._AC_.jpg
# Index in DB: 58365
# Processed 57580/98662: https://m.media-amazon.com/images/I/4138qvOPlnL._AC_.jpg
# Index in DB: 58366
# Processed 57581/98662: https://m.media-amazon.com/images/I/41zSyr3VPWL._AC_.jpg
# Index in DB: 58367
# Processed 57582/98662: https://m.media-amazon.com/images/I/41yPotoDHjL._AC_.jpg
# Index in DB: 58368
# Processed 57583/98662: https://m.media-amazon.com/images/I/51f4xYcdkuL._AC_.jpg
# Index in DB: 58369
# Processed 57584/98662: https://m.media-amazon.com/images/I/41gS7hoqLoL._AC_.jpg
# Index in DB: 58370
# Processed 57585/98662: https://m.media-amazon.com/images/I/41CuVIBR4mL._AC_.jpg
# Index in DB: 58371
# Processed 57586/98662: https://m.media-amazon.com/images/I/41gBrst3yfL._AC_.jpg
# Index in DB: 58372
# Processed 57587/98662: https://m.media-amazon.com/images/I/31-+9vPXnLL._AC_.jpg
# Index in DB: 58373
# Processed 57588/98662: https://m.media-amazon.com/images/I/31ihmdk-plL._AC_.jpg
# Index in DB: 58374
# Processed 57589/98662: https://m.media-amazon.com/images/I/41GSdsnZ5UL._AC_.jpg
# Index in DB: 58375
# Processed 57590/98662: https://m.media-amazon.com/images/I/418HNc6ItKS._AC_.jpg
# Index in DB: 58376
# Processed 57591/98662: https://m.media-amazon.com/images/I/31PdN92C+eL._AC_.jpg
# Index in DB: 58377
# Processed 57592/98662: https://m.media-amazon.com/images/I/31nAx0HoQkL._AC_.jpg
# Index in DB: 58378
# Processed 57593/98662: https://m.media-amazon.com/images/I/41-LScn9-eL._AC_.jpg
# Index in DB: 58379
# Processed 57594/98662: https://m.media-amazon.com/images/I/41jq3lxirKL._AC_.jpg
# Index in DB: 58380
# Processed 57595/98662: https://m.media-amazon.com/images/I/41bpBL1Qi+L._AC_.jpg
# Index in DB: 58381
# Processed 57596/98662: https://m.media-amazon.com/images/I/410JS0wLlvL._AC_.jpg
# Index in DB: 58382
# Processed 57597/98662: https://m.media-amazon.com/images/I/31yOYHhHE1L._AC_.jpg
# Index in DB: 58383
# Processed 57598/98662: https://m.media-amazon.com/images/I/31Ov+Z4YCmL._AC_.jpg
# Index in DB: 58384
# Processed 57599/98662: https://m.media-amazon.com/images/I/51r1UgGi+ML._AC_.jpg
# Index in DB: 58385
# Processed 57600/98662: https://m.media-amazon.com/images/I/41sY345NLOL._AC_.jpg
# Index in DB: 58386
# Processed 57601/98662: https://m.media-amazon.com/images/I/41bEcmoi+SL._AC_.jpg
# Index in DB: 58387
# Processed 57602/98662: https://m.media-amazon.com/images/I/518gXaFF2dL._AC_.jpg
# Index in DB: 58388
# Processed 57603/98662: https://m.media-amazon.com/images/I/51Qr4N8dZ6L._AC_.jpg
# Index in DB: 58389
# Processed 57604/98662: https://m.media-amazon.com/images/I/41xukUNxA9L._AC_.jpg
# Index in DB: 58390
# Processed 57605/98662: https://m.media-amazon.com/images/I/418OvqxJhNL._AC_.jpg
# Index in DB: 58391
# Processed 57606/98662: https://m.media-amazon.com/images/I/31cwW6FsufL._AC_.jpg
# Index in DB: 58392
# Processed 57607/98662: https://m.media-amazon.com/images/I/41IgXbhFueL._AC_.jpg
# Index in DB: 58393
# Processed 57608/98662: https://m.media-amazon.com/images/I/31O2nijd61L._AC_.jpg
# Index in DB: 58394
# Processed 57609/98662: https://m.media-amazon.com/images/I/41yEeeF00BL._AC_.jpg
# Index in DB: 58395
# Processed 57610/98662: https://m.media-amazon.com/images/I/41hNH2V4+XL._AC_.jpg
# Index in DB: 58396
# Processed 57611/98662: https://m.media-amazon.com/images/I/51N82IFWruL._AC_.jpg
# Index in DB: 58397
# Processed 57612/98662: https://m.media-amazon.com/images/I/41iUjLfrCQL._AC_.jpg
# Index in DB: 58398
# Processed 57613/98662: https://m.media-amazon.com/images/I/51Y4OCf1HTL._AC_.jpg
# Index in DB: 58399
# Processed 57614/98662: https://m.media-amazon.com/images/I/31AJGqrvaIS._AC_.jpg
# Index in DB: 58400
# Processed 57615/98662: https://m.media-amazon.com/images/I/41+QcKtLZUL._AC_.jpg
# Index in DB: 58401
# Processed 57616/98662: https://m.media-amazon.com/images/I/41ju2mcGJ2L._AC_.jpg
# Index in DB: 58402
# Processed 57617/98662: https://m.media-amazon.com/images/I/51Y2BXX1Z+L._AC_.jpg
# Index in DB: 58403
# Processed 57618/98662: https://m.media-amazon.com/images/I/316RqKrHl2L._AC_.jpg
# Index in DB: 58404
# Processed 57619/98662: https://m.media-amazon.com/images/I/41cWiVTJvML._AC_.jpg
# Index in DB: 58405
# Processed 57620/98662: https://m.media-amazon.com/images/I/41KuFJSDNfL._AC_.jpg
# Index in DB: 58406
# Processed 57621/98662: https://m.media-amazon.com/images/I/41yGEOTjYUL._AC_.jpg
# Index in DB: 58407
# Processed 57622/98662: https://m.media-amazon.com/images/I/01Vyg7-47iL._AC_.jpg
# Index in DB: 58408
# Processed 57623/98662: https://m.media-amazon.com/images/I/411+SnGXkXL._AC_.jpg
# Index in DB: 58409
# Processed 57624/98662: https://m.media-amazon.com/images/I/41Myb8m7NqL._AC_.jpg
# Index in DB: 58410
# Processed 57625/98662: https://m.media-amazon.com/images/I/41JQ-p8aDWL._AC_.jpg
# Index in DB: 58411
# Processed 57626/98662: https://m.media-amazon.com/images/I/41N1LVQpWGL._AC_.jpg
# Index in DB: 58412
# Processed 57627/98662: https://m.media-amazon.com/images/I/41vL5IZ9yBL._AC_.jpg
# Index in DB: 58413
# ...
# Index in DB: 60298
# Processed 59483/98662: https://m.media-amazon.com/images/I/41ECQopB5JL._AC_.jpg
# Index in DB: 60299
# Processed 59484/98662: https://m.media-amazon.com/images/I/41qQ-N1a2UL._AC_.jpg
# Index in DB: 60300
# Processed 59485/98662: https://m.media-amazon.com/images/I/51nibDDzJBL._AC_.jpg
# Index in DB: 60301
# Processed 59486/98662: https://m.media-amazon.com/images/I/41bYf9k3mTL._AC_.jpg
# Index in DB: 60302
# Processed 59487/98662: https://m.media-amazon.com/images/I/41IohzDnUKL._AC_.jpg
# Index in DB: 60303
# Processed 59488/98662: https://m.media-amazon.com/images/I/51JDCsKhheL._AC_.jpg
# Index in DB: 60304
# Processed 59489/98662: https://m.media-amazon.com/images/I/31JiGFA5d6L._AC_.jpg
# Index in DB: 60305
# Processed 59490/98662: https://m.media-amazon.com/images/I/41tnBZpnNqL._AC_.jpg
# Index in DB: 60306
# Processed 59491/98662: https://m.media-amazon.com/images/I/41OOfemDVYL._AC_.jpg
# Index in DB: 60307
# Processed 59492/98662: https://m.media-amazon.com/images/I/310FH2QCvDL._AC_.jpg
# Index in DB: 60308
# Processed 59493/98662: https://m.media-amazon.com/images/I/31bTAwVKSUS._AC_.jpg
# Index in DB: 60309
# Processed 59494/98662: https://m.media-amazon.com/images/I/11qhmY43CgL._AC_.jpg
# Index in DB: 60310
# Processed 59495/98662: https://m.media-amazon.com/images/I/410feaG7dnL._AC_.jpg
# Index in DB: 60311
# Processed 59496/98662: https://m.media-amazon.com/images/I/51WiHqipLaL._AC_.jpg
# Index in DB: 60312
# Processed 59497/98662: https://m.media-amazon.com/images/I/41LFKSad2cL._AC_.jpg
# Index in DB: 60313
# Processed 59498/98662: https://m.media-amazon.com/images/I/51-mYxsk6zL._AC_.jpg
# Index in DB: 60314
# Processed 59499/98662: https://m.media-amazon.com/images/I/41GYzSQNryS._AC_.jpg
# Index in DB: 60315
# Processed 59500/98662: https://m.media-amazon.com/images/I/51qLUGjP44L._AC_.jpg
# Index in DB: 60316
# Processed 59501/98662: https://m.media-amazon.com/images/I/41aBhK-tFcL._AC_.jpg
# Index in DB: 60317
# Processed 59502/98662: https://m.media-amazon.com/images/I/41yPp0-bagL._AC_.jpg
# Index in DB: 60318
# Processed 59503/98662: https://m.media-amazon.com/images/I/418NiROIPXL._AC_.jpg
# Index in DB: 60319
# Processed 59504/98662: https://m.media-amazon.com/images/I/41A+1oUcFDL._AC_.jpg
# Index in DB: 60320
# Processed 59505/98662: https://m.media-amazon.com/images/I/419v8RttUSL._AC_.jpg
# Index in DB: 60321
# Processed 59506/98662: https://m.media-amazon.com/images/I/31je706el8L._AC_.jpg
# Index in DB: 60322
# Processed 59507/98662: https://m.media-amazon.com/images/I/410af-UdMQL._AC_.jpg
# Index in DB: 60323
# Processed 59508/98662: https://m.media-amazon.com/images/I/51uFJX5fv5L._AC_.jpg
# Index in DB: 60324
# Processed 59509/98662: https://m.media-amazon.com/images/I/41V0FSSCaOL._AC_.jpg
# Index in DB: 60325
# Processed 59510/98662: https://m.media-amazon.com/images/I/51c6DVgoxGL._AC_.jpg
# Index in DB: 60326
# Processed 59511/98662: https://m.media-amazon.com/images/I/41Y5LhVDpsL._AC_.jpg
# Index in DB: 60327
# Processed 59512/98662: https://m.media-amazon.com/images/I/41KaKGEyk2L._AC_.jpg
# Index in DB: 60328
# Processed 59513/98662: https://m.media-amazon.com/images/I/412JY68LwOL._AC_.jpg
# Index in DB: 60329
# Processed 59514/98662: https://m.media-amazon.com/images/I/41+o28e6LFL._AC_.jpg
# Index in DB: 60330
# Processed 59515/98662: https://m.media-amazon.com/images/I/4153B-Pb2fL._AC_.jpg
# Index in DB: 60331
# Processed 59516/98662: https://m.media-amazon.com/images/I/41V4oyuLGuL._AC_.jpg
# Index in DB: 60332
# Processed 59517/98662: https://m.media-amazon.com/images/I/41oYq8IUanL._AC_.jpg
# Index in DB: 60333
# Processed 59518/98662: https://m.media-amazon.com/images/I/51G+AV7CIoL._AC_.jpg
# Index in DB: 60334
# Processed 59519/98662: https://m.media-amazon.com/images/I/413kdIxnMpL._AC_.jpg
# Index in DB: 60335
# Processed 59520/98662: https://m.media-amazon.com/images/I/51Yn0iXxx7L._AC_.jpg
# Index in DB: 60336
# Processed 59521/98662: https://m.media-amazon.com/images/I/41XYwFCHVcL._AC_.jpg
# Index in DB: 60337
# Processed 59522/98662: https://m.media-amazon.com/images/I/31k9bKHDXVL._AC_.jpg
# Index in DB: 60338
# Processed 59523/98662: https://m.media-amazon.com/images/I/51BcvU64SkL._AC_.jpg
# Index in DB: 60339
# Processed 59524/98662: https://m.media-amazon.com/images/I/31Qm1SjWTbL._AC_.jpg
# Index in DB: 60340
# Processed 59525/98662: https://m.media-amazon.com/images/I/41kwKSJNB+L._AC_.jpg
# Index in DB: 60341
# Processed 59526/98662: https://m.media-amazon.com/images/I/519b0PMkN1L._AC_.jpg
# Index in DB: 60342
# Processed 59527/98662: https://m.media-amazon.com/images/I/41akOZi6lrL._AC_.jpg
# Index in DB: 60343
# Processed 59528/98662: https://m.media-amazon.com/images/I/41CkqB3na3L._AC_.jpg
# Index in DB: 60344
# Processed 59529/98662: https://m.media-amazon.com/images/I/31Mvz7HyCOL._AC_.jpg
# Index in DB: 60345
# Processed 59530/98662: https://m.media-amazon.com/images/I/41EJGTuv3FL._AC_.jpg
# Index in DB: 60346
# Processed 59531/98662: https://m.media-amazon.com/images/I/41zQ+O94GiL._AC_.jpg
# Index in DB: 60347
# Processed 59532/98662: https://m.media-amazon.com/images/I/51ctYsHnTWL._AC_.jpg
# Index in DB: 60348
# Processed 59533/98662: https://m.media-amazon.com/images/I/31qvULtAMUL._AC_.jpg
# Index in DB: 60349
# Processed 59534/98662: https://m.media-amazon.com/images/I/511pO2PTqGL._AC_.jpg
# Index in DB: 60350
# Processed 59535/98662: https://m.media-amazon.com/images/I/41oVpdHdbjL._AC_.jpg
# Index in DB: 60351
# Processed 59536/98662: https://m.media-amazon.com/images/I/51QQgpljldL._AC_.jpg
# Index in DB: 60352
# Processed 59537/98662: https://m.media-amazon.com/images/I/31jtYKJ+LRS._AC_.jpg
# Index in DB: 60353
# Processed 59538/98662: https://m.media-amazon.com/images/I/319iE-El6iL._AC_.jpg
# Index in DB: 60354
# Processed 59539/98662: https://m.media-amazon.com/images/I/31nr4ns-RVL._AC_.jpg
# Index in DB: 60355
# Processed 59540/98662: https://m.media-amazon.com/images/I/41FqeaKfZ8L._AC_.jpg
# Index in DB: 60356
# Processed 59541/98662: https://m.media-amazon.com/images/I/51lND+ay-YL._AC_.jpg
# Index in DB: 60357
# Processed 59542/98662: https://m.media-amazon.com/images/I/31g0kxT4iSL._AC_.jpg
# Index in DB: 60358
# Processed 59543/98662: https://m.media-amazon.com/images/I/41K0KQnwkWL._AC_.jpg
# Index in DB: 60359
# Processed 59544/98662: https://m.media-amazon.com/images/I/41TFg1Jka3L._AC_.jpg
# Index in DB: 60360
# Processed 59545/98662: https://m.media-amazon.com/images/I/41gV60ZH6oL._AC_.jpg
# Index in DB: 60361
# Processed 59546/98662: https://m.media-amazon.com/images/I/41RjI1zFTYL._AC_.jpg
# Index in DB: 60362
# Processed 59547/98662: https://m.media-amazon.com/images/I/41zszn7TKtL._AC_.jpg
# Index in DB: 60363
# Processed 59548/98662: https://m.media-amazon.com/images/I/41OhkgzQoQL._AC_.jpg
# Index in DB: 60364
# Processed 59549/98662: https://m.media-amazon.com/images/I/41DgMfQO+YL._AC_.jpg
# Index in DB: 60365
# Processed 59550/98662: https://m.media-amazon.com/images/I/31j3YEVtNUL._AC_.jpg
# Index in DB: 60366
# Processed 59551/98662: https://m.media-amazon.com/images/I/31B+VboajGL._AC_.jpg
# Index in DB: 60367
# Processed 59552/98662: https://m.media-amazon.com/images/I/41+By-6hD7L._AC_.jpg
# Index in DB: 60368
# Processed 59553/98662: https://m.media-amazon.com/images/I/41Mi+B0u71S._AC_.jpg
# Index in DB: 60369
# Processed 59554/98662: https://m.media-amazon.com/images/I/41aa+n3ZErL._AC_.jpg
# Index in DB: 60370
# Processed 59555/98662: https://m.media-amazon.com/images/I/510Pl2WdJtL._AC_.jpg
# Index in DB: 60371
# Processed 59556/98662: https://m.media-amazon.com/images/I/51VKy0HZwZL._AC_.jpg
# Index in DB: 60372
# Processed 59557/98662: https://m.media-amazon.com/images/I/51tH3URe+oL._AC_.jpg
# Index in DB: 60373
# Processed 59558/98662: https://m.media-amazon.com/images/I/61hppmNEoFL._AC_.jpg
# Index in DB: 60374
# Processed 59559/98662: https://m.media-amazon.com/images/I/415k2B0h5bL._AC_.jpg
# Index in DB: 60375
# Processed 59560/98662: https://m.media-amazon.com/images/I/417Ahs7bqtL._AC_.jpg
# Index in DB: 60376
# Processed 59561/98662: https://m.media-amazon.com/images/I/41a1r42gT+L._AC_.jpg
# Index in DB: 60377
# Processed 59562/98662: https://m.media-amazon.com/images/I/51X0dPoSqVL._AC_.jpg
# Index in DB: 60378
# Processed 59563/98662: https://m.media-amazon.com/images/I/41CQPLx72JL._AC_.jpg
# Index in DB: 60379
# Processed 59564/98662: https://m.media-amazon.com/images/I/519MzE2TCLL._AC_.jpg
# Index in DB: 60380
# Processed 59565/98662: https://m.media-amazon.com/images/I/41pEpDJQYXL._AC_.jpg
# Index in DB: 60381
# Processed 59566/98662: https://m.media-amazon.com/images/I/51NApO5Mv-S._AC_.jpg
# Index in DB: 60382
# Processed 59567/98662: https://m.media-amazon.com/images/I/31G2Y9vuURL._AC_.jpg
# Index in DB: 60383
# Processed 59568/98662: https://m.media-amazon.com/images/I/41ZxlHkg1IL._AC_.jpg
# Index in DB: 60384
# Processed 59569/98662: https://m.media-amazon.com/images/I/4110bxOeuDL._AC_.jpg
# Index in DB: 60385
# Processed 59570/98662: https://m.media-amazon.com/images/I/31-X28bSovL._AC_.jpg
# Index in DB: 60386
# Processed 59571/98662: https://m.media-amazon.com/images/I/51PYtCvBsFL._AC_.jpg
# Index in DB: 60387
# Processed 59572/98662: https://m.media-amazon.com/images/I/41wUxOZ5mGL._AC_.jpg
# Index in DB: 60388
# Processed 59573/98662: https://m.media-amazon.com/images/I/41PJqQ+5nsL._AC_.jpg
# Index in DB: 60389
# Processed 59574/98662: https://m.media-amazon.com/images/I/41V6b4DSluL._AC_.jpg
# Index in DB: 60390
# Processed 59575/98662: https://m.media-amazon.com/images/I/51MWKgj4mFL._AC_.jpg
# Index in DB: 60391
# Processed 59576/98662: https://m.media-amazon.com/images/I/51dkSiYYg6L._AC_.jpg
# Index in DB: 60392
# Processed 59577/98662: https://m.media-amazon.com/images/I/51JtmivhGoL._AC_.jpg
# Index in DB: 60393
# Processed 59578/98662: https://m.media-amazon.com/images/I/41s9ekdAU4L._AC_.jpg
# Index in DB: 60394
# Processed 59579/98662: https://m.media-amazon.com/images/I/414rHKXrKtL._AC_.jpg
# Index in DB: 60395
# Processed 59580/98662: https://m.media-amazon.com/images/I/31f0Av6EBbL._AC_.jpg
# Index in DB: 60396
# Processed 59581/98662: https://m.media-amazon.com/images/I/41bdqmhewRL._AC_.jpg
# Index in DB: 60397
# Processed 59582/98662: https://m.media-amazon.com/images/I/41mgv24zmhL._AC_.jpg
# Index in DB: 60398
# Processed 59583/98662: https://m.media-amazon.com/images/I/31U-wB0-dfL._AC_.jpg
# Index in DB: 60399
# Processed 59584/98662: https://m.media-amazon.com/images/I/41Bcoq6ODGL._AC_.jpg
# Index in DB: 60400
# Processed 59585/98662: https://m.media-amazon.com/images/I/41hES0-OEES._AC_.jpg
# Index in DB: 60401
# Processed 59586/98662: https://m.media-amazon.com/images/I/41wihTcU+WL._AC_.jpg
# Index in DB: 60402
# Processed 59587/98662: https://m.media-amazon.com/images/I/410FWIxPh0L._AC_.jpg
# Index in DB: 60403
# Processed 59588/98662: https://m.media-amazon.com/images/I/41CbAJxS-jL._AC_.jpg
# Index in DB: 60404
# Processed 59589/98662: https://m.media-amazon.com/images/I/51XHsUmXVrL._AC_.jpg
# Index in DB: 60405
# Processed 59590/98662: https://m.media-amazon.com/images/I/41iORwo1YUL._AC_.jpg
# Index in DB: 60406
# Processed 59591/98662: https://m.media-amazon.com/images/I/515gGJ6h-QL._AC_.jpg
# Index in DB: 60407
# Processed 59592/98662: https://m.media-amazon.com/images/I/51T2kFgIwtL._AC_.jpg
# Index in DB: 60408
# Processed 59593/98662: https://m.media-amazon.com/images/I/41VvFc-fWdL._AC_.jpg
# Index in DB: 60409
# Processed 59594/98662: https://m.media-amazon.com/images/I/418KfEa7FmL._AC_.jpg
# Index in DB: 60410
# Processed 59595/98662: https://m.media-amazon.com/images/I/41pJlas5i+L._AC_.jpg
# Index in DB: 60411
# Processed 59596/98662: https://m.media-amazon.com/images/I/41MWA3nFwvL._AC_.jpg
# Index in DB: 60412
# Processed 59597/98662: https://m.media-amazon.com/images/I/41d737vjPIL._AC_.jpg
# Index in DB: 60413
# Processed 59598/98662: https://m.media-amazon.com/images/I/41o1Q0v2iDL._AC_.jpg
# Index in DB: 60414
# Processed 59599/98662: https://m.media-amazon.com/images/I/41r+lie2ToL._AC_.jpg
# Index in DB: 60415
# Processed 59600/98662: https://m.media-amazon.com/images/I/51eyhTEZH1L._AC_.jpg
# Index in DB: 60416
# Processed 59601/98662: https://m.media-amazon.com/images/I/41kZONjYobL._AC_.jpg
# Index in DB: 60417
# Processed 59602/98662: https://m.media-amazon.com/images/I/51rUzBZzIyL._AC_.jpg
# Index in DB: 60418
# Processed 59603/98662: https://m.media-amazon.com/images/I/419kk14PzPL._AC_.jpg
# Index in DB: 60419
# Processed 59604/98662: https://m.media-amazon.com/images/I/31+dpcLuW6L._AC_.jpg
# Index in DB: 60420
# Processed 59605/98662: https://m.media-amazon.com/images/I/413RI2yT1mL._AC_.jpg
# Index in DB: 60422
# Processed 59606/98662: https://m.media-amazon.com/images/I/418WIirugzL._AC_.jpg
# Index in DB: 60423
# Processed 59607/98662: https://m.media-amazon.com/images/I/615Eoa8TsZL._AC_.jpg
# Index in DB: 60424
# Processed 59608/98662: https://m.media-amazon.com/images/I/51MoDfdFkUL._AC_.jpg
# Index in DB: 60425
# Processed 59609/98662: https://m.media-amazon.com/images/I/414+pv40+uL._AC_.jpg
# Index in DB: 60426
# Processed 59610/98662: https://m.media-amazon.com/images/I/31MADkulZ5L._AC_.jpg
# Index in DB: 60427
# Processed 59611/98662: https://m.media-amazon.com/images/I/41Tmr4YUenL._AC_.jpg
# Index in DB: 60428
# Processed 59612/98662: https://m.media-amazon.com/images/I/41WwmMkWCVL._AC_.jpg
# Index in DB: 60429
# Processed 59613/98662: https://m.media-amazon.com/images/I/51DzTUUpGOS._AC_.jpg
# Index in DB: 60430
# Processed 59614/98662: https://m.media-amazon.com/images/I/51j0rtcX60L._AC_.jpg
# Index in DB: 60431
# Processed 59615/98662: https://m.media-amazon.com/images/I/41BKnmXF2mL._AC_.jpg
# Index in DB: 60432
# Processed 59616/98662: https://m.media-amazon.com/images/I/51w-WT8rDwL._AC_.jpg
# Index in DB: 60433
# Processed 59617/98662: https://m.media-amazon.com/images/I/41rWXVGsNOL._AC_.jpg
# Index in DB: 60434
# Processed 59618/98662: https://m.media-amazon.com/images/I/41g4-8qcsHL._AC_.jpg
# Index in DB: 60435
# Processed 59619/98662: https://m.media-amazon.com/images/I/41kp+V656qL._AC_.jpg
# Index in DB: 60436
# Processed 59620/98662: https://m.media-amazon.com/images/I/41Xn9kqxkpL._AC_.jpg
# Index in DB: 60437
# Processed 59621/98662: https://m.media-amazon.com/images/I/41HXk60a-PL._AC_.jpg
# Index in DB: 60438
# Processed 59622/98662: https://m.media-amazon.com/images/I/51jI6+PFkVL._AC_.jpg
# Index in DB: 60439
# Processed 59623/98662: https://m.media-amazon.com/images/I/41JONlrvrqL._AC_.jpg
# Index in DB: 60440
# Processed 59624/98662: https://m.media-amazon.com/images/I/51pOdpDPmdL._AC_.jpg
# Index in DB: 60441
# Processed 59625/98662: https://m.media-amazon.com/images/I/41e4IlMRGaL._AC_.jpg
# Index in DB: 60442
# Processed 59626/98662: https://m.media-amazon.com/images/I/41NCMdQq8iL._AC_.jpg
# Index in DB: 60443
# Processed 59627/98662: https://m.media-amazon.com/images/I/41ImqFPvbvL._AC_.jpg
# Index in DB: 60444
# Processed 59628/98662: https://m.media-amazon.com/images/I/41uYjJVnWNL._AC_.jpg
# Index in DB: 60445
# Processed 59629/98662: https://m.media-amazon.com/images/I/51+RQikPjTL._AC_.jpg
# Index in DB: 60446
# Processed 59630/98662: https://m.media-amazon.com/images/I/51LAzWDDRDL._AC_.jpg
# Index in DB: 60447
# Processed 59631/98662: https://m.media-amazon.com/images/I/41H5xyvnhHL._AC_.jpg
# Index in DB: 60448
# Processed 59632/98662: https://m.media-amazon.com/images/I/31GCTIF9EcL._AC_.jpg
# Index in DB: 60449
# Processed 59633/98662: https://m.media-amazon.com/images/I/41quy8tyDXL._AC_.jpg
# Index in DB: 60450
# Processed 59634/98662: https://m.media-amazon.com/images/I/41ckE0e0DnL._AC_.jpg
# Index in DB: 60451
# Processed 59635/98662: https://m.media-amazon.com/images/I/31ArIzUOq+L._AC_.jpg
# Index in DB: 60452
# Processed 59636/98662: https://m.media-amazon.com/images/I/51IynbkO1-L._AC_.jpg
# Index in DB: 60453
# Processed 59637/98662: https://m.media-amazon.com/images/I/41Q6EfDVOUL._AC_.jpg
# Index in DB: 60454
# Processed 59638/98662: https://m.media-amazon.com/images/I/51FZZ9REakL._AC_.jpg
# Index in DB: 60455
# Processed 59639/98662: https://m.media-amazon.com/images/I/31xGqXbkbUL._AC_.jpg
# Index in DB: 60456
# Processed 59640/98662: https://m.media-amazon.com/images/I/41rfn80WGnL._AC_.jpg
# Index in DB: 60457
# Processed 59641/98662: https://m.media-amazon.com/images/I/51zrG8ZyCCL._AC_.jpg
# Index in DB: 60458
# Processed 59642/98662: https://m.media-amazon.com/images/I/41cTyDbo0cL._AC_.jpg
# Index in DB: 60459
# Processed 59643/98662: https://m.media-amazon.com/images/I/41fXV+uuHWL._AC_.jpg
# Index in DB: 60460

# %% [markdown]
# ## Retriever

# %%
# Load the index
index_path = "/content/drive/MyDrive/EXPORT_faiss_size_100000_CLIP_idx_50000_20250417024756.index"
index = faiss.read_index(index_path)

# %%
# Device setup
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Load CLIP model
model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')
model = model.to(device).eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]

# %%
def search_text(query: str, top_k: int = 5):
    # Encode text to CLIP embedding
    with torch.no_grad():
        text_tokens = open_clip.tokenize([query]).to(device)
        text_embedding = model.encode_text(text_tokens).cpu().numpy().astype('float32')
        text_embedding /= np.linalg.norm(text_embedding)  # normalize for cosine similarity

    # Search FAISS index
    D, I = index.search(text_embedding, top_k)
    print(I[0])
    results = [(images_url_dict[i], float(D[0][j])) for j, i in enumerate(I[0])]
    return results

# %%
from IPython.display import display, Image as IPImage

results = search_text("A pair of red pants", top_k=5)
for url, score in results:
    print(f"{score:.3f} - {url}")

for url, score in results:
    print(f"{score:.3f} - {url}")
    display(IPImage(url=url))
# Out:
# [39003 36479 36845 50381 13671]
# 0.307 - https://m.media-amazon.com/images/I/41gO3yeh2qL._AC_.jpg
# 0.304 - https://m.media-amazon.com/images/I/31soIbV-OFL._AC_.jpg
# 0.303 - https://m.media-amazon.com/images/I/31J2MO63i-L._AC_.jpg
# 0.302 - https://m.media-amazon.com/images/I/317AZDXmUVL._AC_.jpg
# 0.301 - https://m.media-amazon.com/images/I/31eUc7WQ+3L._AC_.jpg
# 0.307 - https://m.media-amazon.com/images/I/41gO3yeh2qL._AC_.jpg
# <img src="https://m.media-amazon.com/images/I/41gO3yeh2qL._AC_.jpg"/>
# 0.304 - https://m.media-amazon.com/images/I/31soIbV-OFL._AC_.jpg
# <img src="https://m.media-amazon.com/images/I/31soIbV-OFL._AC_.jpg"/>
# 0.303 - https://m.media-amazon.com/images/I/31J2MO63i-L._AC_.jpg
# <img src="https://m.media-amazon.com/images/I/31J2MO63i-L._AC_.jpg"/>
# 0.302 - https://m.media-amazon.com/images/I/317AZDXmUVL._AC_.jpg
# <img src="https://m.media-amazon.com/images/I/317AZDXmUVL._AC_.jpg"/>
# 0.301 - https://m.media-amazon.com/images/I/31eUc7WQ+3L._AC_.jpg
# <img src="https://m.media-amazon.com/images/I/31eUc7WQ+3L._AC_.jpg"/>
